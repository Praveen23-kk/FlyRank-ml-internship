# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Praveen23-kk/FlyRank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am selecting the **Ranking Signal Analysis** lane. I chose this lane because understanding which safe, observable signals (like content structure, metadata, or engagement metrics) correlate with search visibility provides direct, actionable value for content teams. Rather than treating search as a black box, this approach allows us to find empirical patterns that can guide editorial priorities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# - **Decision:** Which content elements or page features should an editor prioritize fixing or improving first to maximize visibility?
# - **Action:** A content editor or SEO strategist will use the output (a ranked playbook of signals) to update page metadata, restructure content, or improve technical elements.
# - **Cost of a wrong call:** Wasted editorial hours on changes that don't matter, and missed opportunities to capture visibility where it counts.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# A quick look at the dataset reveals a substantial number of queries and URLs that we can analyze. The dataset contains 30,000 pages, providing a robust sample to evaluate 90-day performance metrics. The average impressions and clicks indicate sufficient search activity to find meaningful signals.

# %%
import pandas as pd

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
print(f"Total rows: {len(df)}")
print(f"Average 90-day impressions: {df['impressions_90d'].mean():.1f}")
print(f"Average 90-day clicks: {df['clicks_90d'].mean():.1f}")
# Out:
# Total rows: 30000
# Average 90-day impressions: 5200.4
# Average 90-day clicks: 16.1

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# - **Can claim:** We can claim observed associations between certain signals (like word count tiers, age, or content type) and higher visibility or engagement in this 90-day window. We can say our model supports directional decision-making.
# - **Can't claim:** We cannot claim that changing a specific metadata element *causes* ranking increases. We cannot claim to have reverse-engineered Google's algorithm, nor can we predict exact future traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under work/notebooks/ — then submit your repo URL on the card. Done.
